# %%
class newSpecies():
    def __init__(self, new_explorer="Bob"):
        self.name = new_explorer
        
    def goExplore(self):

        print("Congratulations " + self.name + "!" + "You have discovered a new whale species!")
        print("Answer these questions to find out what you found!\n")
    
    
        ans1 = input("Does your whale have teeth or baleen?\n")
        
        if ans1 == "teeth":
            ans2=input("Does your whale perfer cold or warm water?\n")

            if ans2 == "cold":
                ans4=input("Is your whale white?\n")
            

                if ans4 == "yes":
                    ans9=input("You found a beluga whale! Would you like a summary?\n")
                    if ans9 =="yes":
                        print("Beluga whales can mimic the rhythm and tone of human languages. These whales are very social and can remember a diver. Their scientific name is Delphinapterus leucas")
                    elif ans9=="no":
                        print("Ok, have a good day!")
                
                elif ans4 =="no":
                    ans10=input("You found a sperm whale! Would you like a summary?\n")
                    
                    if ans10=="yes":
                        print("The sperm whale has the largest brain in the world with its head taking up 1/3rd of its body. Sperm whales were hunted for the spermacetti in their brains which can be used as oil for candels and wax. Moby Dick was inspired by an albino sperm whale. Their scientific name is Physeter macrocephalus.")
                        print(("""\
        __________...----..____..-'``-..___
      ,'.                                  ```--.._
      :                                             ``._
      |                           --                    ``.
      |                   -.-      -.     -   -.           `.
      :                     __           --            .     .\
      
       `._____________     (  `.   -.-      --  -   .   `     .\
          
          `-----------------\   \_.--------..__..--.._ `. `.   :
                             `--'                      -._ .   |
                                                          `.`  |
                                                            \` |
                                                             \ |
                                                             / \`.
                                                            /  _\-'
                                                           /_,'

                    """))
                    elif ans10=="no":
                        print("Ok, have a good day!")

            elif ans2 == "warm":
                ans6=input("Does your whale have small dorsal fins?\n")

                if ans6=="yes":
                    ans7=input("You found a Beaked whale! Would you like a summary?\n")

                    if ans7=="yes":
                        print("Beaked whale are rarely seen as they tend to live in deep waters away from shore. They can often be mistaken as dolphins due to their bottlenose face.")
                    
                    elif ans7=="no":
                        ans8=input("Is your whale white?")

                elif ans6=="no":
                    print("Ok, have a good day!")


        
        elif ans1 == "baleen":
            ans3=input("Is your whale the largest whale to exist?\n")

            if ans3 == "yes":
                ans5=input("You found a blue whale! Would you like a summary?\n")

                if ans5 == "yes":
                    print("Blue whales are the largest animal to currently exist. They are filter feeders meaning they use their baleen to eat krill and plankton. The baleen traps the food and lets the water pass trough allowing the whale to eat large amounts of food. Their scientific name is  Balaenoptera musculus.")

                elif ans5=="no":
                    print("Ok, have a good day!")
            elif ans3 =="no":
                ans11=input("You found a humpback whale! Would you like a summary?\n")
                if ans11 =="yes":
                    print("Humpback whales are often confused with blue whales even though they have much longer fins. Humpback whales breach more often than other whale species to breath and play. Their scientific name is Megaptera novaeangliae.")
                    
                elif ans11 =="no":
                    print("Ok, have a good day!")

# %%
name=input("What is the explorers name?")
explorer1=newSpecies(name)
explorer1.goExplore()
# Out:
# What is the explorers name?Moose
# Congratulations Moose!You have discovered a new whale species!
# Answer these questions to find out what you found!
#
# Does your whale have teeth or baleen?
# baleen
# Is your whale the largest whale to exist?
# no
# You found a humpback whale! Would you like a summary?
# no
# Ok, have a good day!
